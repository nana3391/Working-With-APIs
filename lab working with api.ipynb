# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %%
import json

response = requests.get('https://meowfacts.herokuapp.com/?count=5')
#response
results = response.json()
results
# Out:
# {'data': ['In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#   'All cats have three sets of long hairs that are sensitive to pressure - whiskers, eyebrows,and the hairs between their paw pads.',
#   'The Maine Coone is the only native American long haired breed.',
#   'Cats bury their feces to cover their trails from predators.',
#   'A happy cat holds her tail high and steady.']}

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

cat= pd.DataFrame(results)
cat
# Out:
#                                                 data
# 0  In tigers and tabbies, the middle of the tongu...
# 1  All cats have three sets of long hairs that ar...
# 2  The Maine Coone is the only native American lo...
# 3  Cats bury their feces to cover their trails fr...
# 4        A happy cat holds her tail high and steady.

# %%
import json

response = requests.get('https://bobsburgers-api.herokuapp.com/characters/?limit=9&skip=99')
#response
results = response.json()
results
# Out:
# [{'id': 100,
#   'name': 'Critter',
#   'image': 'https://bobsburgers-api.herokuapp.com/images/characters/100.jpg',
#   'age': '20s-30s',
#   'gender': 'Male',
#   'hairColor': 'Brown',
#   'relatives': [{'_id': '6422cb8d928fca2484b47a2a',
#     'name': 'Sidecar',
#     'wikiUrl': 'https://bobs-burgers.fandom.com/wiki/Sidecar',
#     'relationship': 'son'},
#    {'_id': '6422cb8d928fca2484b47a2b',
#     'name': 'Mudflap',
#     'wikiUrl': 'https://bobs-burgers.fandom.com/wiki/Mudflap',
#     'relationship': 'wife',
#     'url': 'https://bobsburgers-api.herokuapp.com/characters/352'}],
#   'occupation': 'Chapter president of the One Eyed Snakes/Employee at What the Tech',
#   'firstEpisode': '"Ear-sy Rider"',
#   'voicedBy': 'Robert Ben Garant',
#   'url': 'https://bobsburgers-api.herokuapp.com/characters/100',
#   'wikiUrl': 'https://bobs-burgers.fandom.com/wiki/Critter'},
#  {'id': 101,
#   'name': 'Curt',
# ...

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

bobs= pd.DataFrame(results)
bobs
# Out:
#     id               name                                              image  \
# 0  100            Critter  https://bobsburgers-api.herokuapp.com/images/c...
# 1  101               Curt  https://bobsburgers-api.herokuapp.com/images/c...
# 2  102       Cynthia Bush  https://bobsburgers-api.herokuapp.com/images/c...
# 3  103             Dahlia  https://bobsburgers-api.herokuapp.com/images/c...
# 4  104   Dakota Applebaum  https://bobsburgers-api.herokuapp.com/images/c...
# 5  105     Dalton Crespin  https://bobsburgers-api.herokuapp.com/images/c...
# 6  106              Damon  https://bobsburgers-api.herokuapp.com/images/c...
# 7  107  Daniel Cunningham  https://bobsburgers-api.herokuapp.com/images/c...
# 8  108    Danny Duszynski  https://bobsburgers-api.herokuapp.com/images/c...
#
#                                age  gender      hairColor  \
# 0                          20s-30s    Male          Brown
# 1  13 (30 years ago), 43 (current)    Male          Brown
# ...

# %%
# cannot be flatten, because there are to many NaN values in "relatives"

# %%
import json

response = requests.get('https://dog.ceo/api/breeds/image/random')
#response
results = response.json()
results
# Out:
# {'message': 'https://images.dog.ceo/breeds/terrier-norwich/n02094258_188.jpg',
#  'status': 'success'}

# %%
import pandas as pd
pd.set_option("display.max_rows", 0)

dog= pd.DataFrame(results)
dog
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/0v/17715kfs38508b6c7dzmsg8h0000gn/T/ipykernel_2394/1383423272.py in <module>
#       2 pd.set_option("display.max_rows", 0)
#       3
# ----> 4 dog= pd.DataFrame(results)
#       5 dog
#       6
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...
